# %% [markdown]
# <a href="https://colab.research.google.com/github/lucasjamiro/Experiment-PPGCG/blob/main/GA155%20-%20SQL%20magic%20bairros.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# install
# !apt install postgresql postgresql-contrib &>log
# !apt install gdal-bin
# !service postgresql start
# !sudo -u postgres psql -c "CREATE USER root WITH SUPERUSER"
# set connection
# %load_ext sql
# %config SqlMagic.feedback=False
# %config SqlMagic.autopandas=True
# %sql postgresql+psycopg2://@/postgres
# !apt install postgis
# Setup a password `postgres` for username `postgres`
# !sudo -u postgres psql -U postgres -c "ALTER USER postgres PASSWORD 'postgres';"
# Out:
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# gdal-bin is already the newest version (3.8.4+dfsg-1~jammy0).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
#  * Starting PostgreSQL 14 database server
#    ...done.
# ERROR:  role "root" already exists
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql
# Reading package lists... Done
# Building dependency tree... Done
# Reading state information... Done
# postgis is already the newest version (3.4.1+dfsg-1~jammy0).
# 0 upgraded, 0 newly installed, 0 to remove and 2 not upgraded.
# ALTER ROLE

# %%
# !pip install --upgrade ipython-sql prettytable
# Out:
# Requirement already satisfied: ipython-sql in /usr/local/lib/python3.12/dist-packages (0.5.0)
# Requirement already satisfied: prettytable in /usr/local/lib/python3.12/dist-packages (3.17.0)
# Requirement already satisfied: ipython in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (7.34.0)
# Requirement already satisfied: sqlalchemy>=2.0 in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (2.0.48)
# Requirement already satisfied: sqlparse in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (0.5.5)
# Requirement already satisfied: six in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (1.17.0)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.12/dist-packages (from ipython-sql) (0.2.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.12/dist-packages (from prettytable) (0.6.0)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=2.0->ipython-sql) (3.3.2)
# Requirement already satisfied: typing-extensions>=4.6.0 in /usr/local/lib/python3.12/dist-packages (from sqlalchemy>=2.0->ipython-sql) (4.15.0)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (75.2.0)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (0.19.2)
# Requirement already satisfied: decorator in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (3.0.52)
# Requirement already satisfied: pygments in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (2.20.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.12/dist-packages (from ipython->ipython-sql) (4.9.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.12/dist-packages (from jedi>=0.16->ipython->ipython-sql) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.12/dist-packages (from pexpect>4.3->ipython->ipython-sql) (0.7.0)

# %%
import prettytable

# %%
# %sql CREATE EXTENSION postgis
# Out:
#  * postgresql+psycopg2://@/postgres
# (psycopg2.errors.DuplicateObject) extension "postgis" already exists
#
# [SQL: CREATE EXTENSION postgis]
# (Background on this error at: https://sqlalche.me/e/20/f405)

# %%
# Preparando o ambiente no Google Drive:

#importando a biblioteca
from google.colab import drive

# Isso irá pedir sua autorização
drive.mount('/content/drive',force_remount=True)

# Agora, seu Drive estará disponível em: /content/drive/My Drive
# Out:
# Mounted at /content/drive

# %%
# !ogr2ogr -f PostgreSQL PG:"host=localhost user=postgres password=postgres dbname=postgres" -s_srs EPSG:4326 -t_srs EPSG:4326 -nln public.bairros1 -lco GEOMETRY_NAME=geom -overwrite /content/drive/MyDrive/Dados/bairros_wgs84.geojson

# %%
df_bairros = %sql SELECT * FROM bairros1
df_bairros.head()
# Out:
#  * postgresql+psycopg2://@/postgres
#    ogc_fid  objectid  codigo               tipo            nome  \
# 0        1       111    29.0  DIVISA DE BAIRROS       SEMINÁRIO
# 1        2       112    23.0  DIVISA DE BAIRROS     GUABIROTUBA
# 2        3       113    27.0  DIVISA DE BAIRROS          PORTÃO
# 3       52       114     4.0  DIVISA DE BAIRROS  ALTO DA GLÓRIA
# 4        4       115    45.0  DIVISA DE BAIRROS       MOSSUNGUÊ
#
#                           fonte  cd_regiona                 nm_regiona  \
# 0  Decreto Municipal 774 / 1975         7.0            REGIONAL PORTÃO
# 1  Decreto Municipal 774 / 1975         3.0            REGIONAL CAJURU
# 2  Decreto Municipal 774 / 1975         7.0            REGIONAL PORTÃO
# 3  Decreto Municipal 774 / 1975         1.0            REGIONAL MATRIZ
# 4  Decreto Municipal 774 / 1975         5.0  REGIONAL SANTA FELICIDADE
#
#      shape_area     shape_len  \
# 0  2.123845e+06   7068.306546
# 1  2.654431e+06   6576.157173
# 2  5.858496e+06  10839.074473
# 3  8.754828e+05   4057.149108
# 4  3.365441e+06   9125.525056
#
#                                                 geom
# 0  0106000020E61000000100000001030000000100000007...
# 1  0106000020E610000001000000010300000001000000B2...
# 2  0106000020E6100000010000000103000000010000007B...
# 3  0106000020E6100000010000000103000000010000004F...
# 4  0106000020E6100000010000000103000000010000009E...

# %%
# %sql CREATE OR REPLACE VIEW bairro_selecionado AS SELECT *, ST_AsText(geom) as geometria from bairros1 WHERE nome = 'Crisro rei'
df = %sql SELECT * from bairro_selecionado
df.head()
# Out:
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
# Empty DataFrame
# Columns: []
# Index: []

# %%
df1 = %sql SELECT bairros1.*, ST_AsText(bairros1.geom) as geometria from bairros1, bairro_selecionado WHERE ST_touches(bairro_selecionado.geom,bairros1.geom) = TRUE
df1
# Out:
#  * postgresql+psycopg2://@/postgres
# Empty DataFrame
# Columns: []
# Index: []

# %%
bairroin = input("Digite o nome do bairro: ")

# %sql SET SESSION search_path TO public
df = %sql SELECT shape_area FROM bairros1 WHERE LOWER(nome) = LOWER(:bairroin)

if not df.empty:
    df['shape_area'] = df['shape_area'] / 1000000
    print(f"Área do bairro {bairroin}: {df['shape_area'].iloc[0]:.2f} km²")
else:
    print(f"O bairro '{bairroin}' não foi encontrado. Por favor, verifique o nome (ex: 'SEMINÁRIO').")

df.head()
# Out:
# Digite o nome do bairro: cristo rei
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
# Área do bairro cristo rei: 1.45 km²
#    shape_area
# 0    1.446992

# %%
from ipywidgets import Dropdown
from IPython.display import display, clear_output
import pandas as pd

# 1. Buscar bairros com SQLMagic
# O resultado já é um dataframe pandas por padrão
bairro_select = %sql SELECT codigo, nome FROM bairros1 ORDER BY nome

# 2. Criar Dropdown com os bairros
comboMun = Dropdown(
    options=[(row['nome'], row['codigo']) for _, row in bairro_select.iterrows()],
    description='Bairro:'
)

# 3. Definir função de callback
def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        clear_output(wait=True)
        display(comboMun)

        # Executa consulta com o código selecionado e acha o nome
        selected_codigo = comboMun.value
        selected_bairro_name = bairro_select[bairro_select['codigo'] == selected_codigo]['nome'].iloc[0]

        # %sql SET SESSION search_path TO public
        df = %sql SELECT shape_area FROM bairros1 WHERE LOWER(nome) = LOWER(:selected_bairro_name)

        if not df.empty:
            df['shape_area'] = df['shape_area'] / 1000000
            print(f"Área do bairro {selected_bairro_name}: {df['shape_area'].iloc[0]:.2f} km²")
        else:
            # Idealmente essa função não deve ser ativada nunca
            print(f"O bairro '{selected_bairro_name}' não foi encontrado. Por favor, verifique o nome.")

# 4. Associar a função ao Dropdown
comboMun.observe(on_change)

# 5. Mostrar o Dropdown na interface
display(comboMun)
# Out:
# Dropdown(description='Bairros:', options=(('ABRANCHES', 50.0), ('ÁGUA VERDE', 9.0), ('AHÚ', 14.0), ('ALTO BOQU…
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
# Área do bairro ABRANCHES: 4.32 km²

# %%
from ipywidgets import Dropdown
from IPython.display import display, clear_output
import pandas as pd
import geopandas as gpd
import folium
from shapely import wkt

# 1. Buscar bairros
df_bairros = %sql SELECT codigo, nome FROM bairros1 ORDER BY nome

# 2. Criar Dropdown
comboMun = Dropdown(
    options=[(row['nome'], row['codigo']) for _, row in df_bairros.iterrows()],
    description='Bairros:'
)

# 3. Callback ao mudar a seleção
def on_change(change):
    if change['type'] == 'change' and change['name'] == 'value':
        clear_output(wait=True)
        display(comboMun)

        codigo = comboMun.value

        # Consulta área
        # Executa consulta com o código selecionado e acha o nome
        selected_codigo = comboMun.value
        selected_bairro_name = bairro_select[bairro_select['codigo'] == selected_codigo]['nome'].iloc[0]

        # %sql SET SESSION search_path TO public
        df = %sql SELECT shape_area FROM bairros1 WHERE LOWER(nome) = LOWER(:selected_bairro_name)

        if not df.empty:
            df['shape_area'] = df['shape_area'] / 1000000
            print(f"Área do bairro {selected_bairro_name}: {df['shape_area'].iloc[0]:.2f} km²")
        else:
            # Idealmente essa função não deve ser ativada nunca
            print(f"O bairro '{selected_bairro_name}' não foi encontrado. Por favor, verifique o nome.")

        # Consulta geometria como WKT para exibir no mapa
        consulta_geom = f"""
            SELECT ST_AsText(ST_Transform(geom, 4326)) AS geom
            FROM bairros1
            WHERE codigo = '{codigo}'
        """
        resultado_geom = %sql $consulta_geom
        resultado_geom['geom'] = resultado_geom['geom'].apply(wkt.loads)
        gdf = gpd.GeoDataFrame(resultado_geom, geometry="geom", crs="EPSG:4326")

        # Criar o mapa
        centro = gdf.geometry.centroid.iloc[0]
        mapa = folium.Map(location=[centro.y, centro.x], zoom_start=10)
        folium.GeoJson(gdf).add_to(mapa)

        display(mapa)

# 4. Associar o callback
comboMun.observe(on_change)

# 5. Exibir a interface
display(comboMun)
# Out:
# Dropdown(description='Bairros:', index=30, options=(('ABRANCHES', 50.0), ('ÁGUA VERDE', 9.0), ('AHÚ', 14.0), (…
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
# /tmp/ipykernel_868/3050602825.py:56: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centro = gdf_sel.geometry.centroid.iloc[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c577907c99c76983f09f8cf98b08cb7a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c577907c99c76983f09f8cf98b08cb7a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c577907c99c76983f09f8cf98b08cb7a = L.map(
#                 &quot;map_c577907c99c76983f09f8cf98b08cb7a&quot;,
#                 {
#                     center: [-25.434482476764035, -49.24332800998948],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7a135d4eb2805451dd2dd23a022b7386 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7a135d4eb2805451dd2dd23a022b7386.addTo(map_c577907c99c76983f09f8cf98b08cb7a);
#
#
#         function geo_json_0833fa64c603ea17710be65d670ce200_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_0833fa64c603ea17710be65d670ce200_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_0833fa64c603ea17710be65d670ce200 = L.geoJson(null, {
#                 onEachFeature: geo_json_0833fa64c603ea17710be65d670ce200_onEachFeature,
#
#                 style: geo_json_0833fa64c603ea17710be65d670ce200_styler,
#             ...{
# }
#         });
#
#         function geo_json_0833fa64c603ea17710be65d670ce200_add (data) {
#             geo_json_0833fa64c603ea17710be65d670ce200
#                 .addData(data);
#         }
#             geo_json_0833fa64c603ea17710be65d670ce200_add({&quot;bbox&quot;: [-49.255705713008005, -25.441991829457884, -49.23358245901297, -25.42793459584282], &quot;features&quot;: [{&quot;bbox&quot;: [-49.255705713008005, -25.441991829457884, -49.23358245901297, -25.42793459584282], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-49.236391075281524, -25.43481332845368], [-49.23530118572857, -25.436415386528026], [-49.235296662590606, -25.436422038039158], [-49.23529587065232, -25.43642191501418], [-49.235293727911504, -25.436421584004794], [-49.235227649364006, -25.436411370391333], [-49.23445933090622, -25.436292601363544], [-49.233987294387475, -25.436219630535472], [-49.233986621711075, -25.436219527121114], [-49.233979043139314, -25.43621835600117], [-49.233955643865585, -25.436214738232128], [-49.233954552257025, -25.436233831564024], [-49.233950727347484, -25.436300576898862], [-49.23393762658478, -25.436529168432163], [-49.23393428077479, -25.436587568886956], [-49.23392867042359, -25.436685527603057], [-49.23392647011517, -25.436723927300854], [-49.233878369057486, -25.43699250111795], [-49.233865923711484, -25.43706201356463], [-49.2338355199935, -25.437231777763593], [-49.23372740817982, -25.437835443272505], [-49.23366710100793, -25.43817218225189], [-49.23360916262077, -25.438580545273886], [-49.233601143484975, -25.438684395623437], [-49.23358680808845, -25.438870040927966], [-49.23358565074354, -25.43888502233288], [-49.23358245901297, -25.43892635140257], [-49.23358276906306, -25.43895443155668], [-49.23358351343813, -25.439021997719397], [-49.23358618731149, -25.43926465616219], [-49.233607947572274, -25.440221873498736], [-49.23361894483752, -25.440705655915654], [-49.23362576199695, -25.441005600833023], [-49.23363436258355, -25.441372392635646], [-49.233645175931606, -25.441833462146544], [-49.2336458385364

# %%
from ipywidgets import Dropdown
from IPython.display import display, clear_output
import pandas as pd
import geopandas as gpd
import folium
from shapely import wkt

# 1. Buscar bairros
df_bairros = %sql SELECT codigo, nome FROM bairros1 ORDER BY nome

# 2. Criar Dropdown
comboMun = Dropdown(
    options=[(row['nome'], row['codigo']) for _, row in df_bairros.iterrows()],
    description='Bairros:'
)

# 3. Função para atualizar o mapa
def atualizar_mapa(change):
    if change['type'] == 'change' and change['name'] == 'value':
        clear_output(wait=True)
        display(comboMun)

        codigo = comboMun.value

        # Consulta bairro selecionado (original shape)
        consulta_sel = f"""
            SELECT codigo, nome, ST_AsText(ST_Transform(geom, 4326)) AS geom
            FROM bairros1
            WHERE codigo = '{codigo}'
        """
        df_sel = %sql $consulta_sel
        df_sel['geometry'] = df_sel['geom'].apply(wkt.loads)
        gdf_sel = gpd.GeoDataFrame(df_sel, geometry='geometry', crs='EPSG:4326')

        # Consulta vizinhos, usando o buffer do bairro selecionado para a detecção de 'touches'
        consulta_viz = f"""
            SELECT codigo, nome, ST_AsText(ST_Transform(geom, 4326)) AS geom
            FROM bairros1
            WHERE codigo != '{codigo}'
              AND ST_Intersects(
                    (SELECT ST_Buffer(ST_Transform(geom, 3857), 10) FROM bairros1 WHERE codigo = '{codigo}'),
                    ST_Transform(bairros1.geom, 3857)
                  )
        """
        df_viz = %sql $consulta_viz

        # Adiciona verificação para df_viz vazio
        if not df_viz.empty:
            df_viz['geometry'] = df_viz['geom'].apply(wkt.loads)
            gdf_viz = gpd.GeoDataFrame(df_viz, geometry='geometry', crs='EPSG:4326')
        else:
            # Cria um GeoDataFrame vazio se não houver vizinhos
            gdf_viz = gpd.GeoDataFrame(columns=['codigo', 'nome', 'geom', 'geometry'], geometry='geometry', crs='EPSG:4326')

        # Criar o mapa
        centro = gdf_sel.geometry.centroid.iloc[0]
        mapa = folium.Map(location=[centro.y, centro.x], zoom_start=10)

        # Adiciona bairro selecionado em azul com tooltip (formato original)
        folium.GeoJson(gdf_sel,
                       name="Bairro selecionado",
                       style_function=lambda x: {"fillColor": "blue", "color": "blue", "weight": 2, "fillOpacity": 0.4},
                       tooltip=folium.GeoJsonTooltip(fields=['nome'], aliases=['Bairro:'])
                      ).add_to(mapa)

        # Adiciona vizinhos em vermelho com tooltip
        folium.GeoJson(gdf_viz,
                       name="Vizinhos",
                       style_function=lambda x: {"fillColor": "red", "color": "red", "weight": 1.5, "fillOpacity": 0.3},
                       tooltip=folium.GeoJsonTooltip(fields=['nome'], aliases=['Bairros:'])
                      ).add_to(mapa)

        folium.LayerControl().add_to(mapa)
        display(mapa)

# 4. Conectar a função ao Dropdown
comboMun.observe(atualizar_mapa)

# 5. Mostrar o Dropdown
display(comboMun)
# Out:
# Dropdown(description='Bairros:', index=30, options=(('ABRANCHES', 50.0), ('ÁGUA VERDE', 9.0), ('AHÚ', 14.0), (…
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
# /tmp/ipykernel_868/3122467364.py:59: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab10' if num_colors <= 10 else 'gist_rainbow', num_colors)
# /tmp/ipykernel_868/3122467364.py:69: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centro = gdf_sel.geometry.centroid.iloc[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_84119f52ae5a8d5655bc026912eb17dc {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position: fixed; bottom: 50px; left: 50px; width: 200px; background-color: white; border:2px solid grey; z-index:9999; font-size:14px; padding: 10px;&quot;&gt;&lt;b&gt;Tipo de Instituição&lt;/b&gt;&lt;br&gt;&lt;i style=&quot;background:#1f77b4; width:10px; height:10px; display:inline-block; margin-right:5px;&quot;&gt;&lt;/i&gt;Ensino Fundamental&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_84119f52ae5a8d5655bc026912eb17dc&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_84119f52ae5a8d5655bc026912eb17dc = L.map(
#                 &quot;map_84119f52ae5a8d5655bc026912eb17dc&quot;,
#                 {
#                     center: [-25.434482476764035, -49.24332800998948],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_586328202e4e65aa2b12680c8096807f = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_586328202e4e65aa2b12680c8096807f.addTo(map_84119f52ae5a8d5655bc026912eb17dc);
#
#
#         function geo_json_45fa27caab7e39ce1542f485a17ac3c7_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_45fa27caab7e39ce1542f485a17ac3c7_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_45fa27caab7e39ce1542f485a17ac3c7 = L.geoJson(null, {
#                 onEachFeature: geo_json_45fa27caab7e39ce1542f485a17ac3c7_onEachFeature,
#
#                 style: geo_json_45fa27caab7e39ce1542f485a17ac3c7_styler,
#             ...{
# }
#         });
#
#         function geo_json_45fa27caab7e39ce1542f485a17ac3c7_add (data) {
#             geo_json_45fa27caab7e39ce1542f485a17ac3c7
#                 .addData(data);
#         }
#             geo_json_45fa27caab7e39ce1542f485a17ac3c7_add({&quot;bbox&quot;: [-49.255705713008005, -25.441991829457884, -49.23358245901297, -25.42793459584282], &quot;features&quot;: [{&quot;bbox&quot;: [-49.255705713008005, -25.441991829457884, -49.23358245901297, -25.42793459584282], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-49.236391075281524, -25.43481332845368], [-49.23530118572857, -25.436415386528026], [-49.235296662590606, -25.436422038039158], [-49.23529587065232, -25.43642191501418], [-49.235293727911504, -25.436421584004794], [-49.235227649364006, -25.436411370391333], [-49.23445933090622, -25.436292601363544], [-49.233987294387475, -25.436219630535472], [-49.233986621711075, -25.436219527121114], [-49.233979043139314, -25.43621835600117], [-49.233955643865585, -25.436214738232128], [-49.233954552257025, -25.436233831564024], [-49.233950727347484, -25.436300576898862], [-49.23393762658478, -25.436529168432163], [-49.23393428077479, -25.436587568886956], [-49.23392867042359, -25.436685527603057], [-49.23392647011517, -25.436723927300854], [-49.233878369057486, -25.43699250111795], [-49.233865923711484, -25.43706201356463], [-49.2338355199935, -25.437231777763593], [-49.23372740817982, -25.437835443272505], [-49.23366710100793, -25.43817218225189], [-49.23360916262077, -25.438580545273886], [-49.233601143484975, -25.438684395623437], [-49.23358680808845, -25.438870040927966], [-49.23358565074354, -25.43888502233288], [-49.23358245901297, -25.43892635140257], [-49.23358276906306, -25.43895443155668], [-49.23358351343813, -25.439021997719397], [-49.23358618731149, -25.43926465616219], [-49.233607947572274, -25.440221873498736], [-49.23361894483752, -25.440705655915654], [-49.23362576199695, -25.441005600833023], [-49.23363436258355, -25.441372392635646], [-49.233645175931606, -25.441833462146544], [-49.23364583853643, -25.44186179228484], [-49.2336458831889, -25.441863639824053], [-49.23364592438188, -25.44186543332217], [-49.233648769649264, -25.44198677789369

# %%
# !sudo shp2pgsql -c -I -s 4326 -W "latin1" /content/drive/MyDrive/Dados/ESCOLA_MUNICIPAL.shp public.escolas1 | psql -d postgres -U root /dev/null 2>&1

df_escolas = %sql SELECT * FROM escolas1
df_escolas.head()
# Out:
# Field cd_equi is an FTDouble with width 10 and precision 0
# Field cd_tema is an FTDouble with width 10 and precision 0
# Field id_equip is an FTDouble with width 10 and precision 0
# Field cd_tipo_eq is an FTDouble with width 10 and precision 0
# Field cd_dep_adm is an FTDouble with width 10 and precision 0
# Field cd_distrit is an FTDouble with width 10 and precision 0
# Field cd_equi_di is an FTDouble with width 10 and precision 0
# Field cd_mantene is an FTDouble with width 10 and precision 0
# Field lat_sirgas is an FTDouble with width 19 and precision 8
# Field lon_sirgas is an FTDouble with width 19 and precision 8
# Shapefile type: Point
# Postgis type: POINT[2]
# psql: warning: extra command-line argument "/dev/null" ignored
# SET
# SET
# BEGIN
# ERROR:  relation "escolas1" already exists
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ERROR:  current transaction is aborted, commands ignored until end of transaction block
# ROLLBACK
# ANALYZE
#  * postgresql+psycopg2://@/postgres
#    gid  cd_equi  cd_local  cd_tema      tema  id_equip equipament  cd_tipo_eq  \
# 0    1  10880.0  41149378     11.0  EDUCAÇÃO      22.0     Escola         1.0
# 1    2   5315.0  41537904     11.0  EDUCAÇÃO      22.0     Escola         1.0
# 2    3   8417.0      None     11.0  EDUCAÇÃO      22.0     Escola         1.0
# 3    4   5314.0  41537890     11.0  EDUCAÇÃO      22.0     Escola         1.0
# 4    5   1620.0  41133323     11.0  EDUCAÇÃO      22.0     Escola         1.0
#
#             tipo_equi  cd_dep_adm  ...  dt_atualiz  \
# 0  Ensino Fundamental         3.0  ...  2024-03-08
# 1  Ensino Fundamental         3.0  ...  2024-03-08
# 2  Ensino Fundamental         3.0  ...  2024-07-08
# 3  Ensino Fundamental         3.0  ...  2024-09-16
# 4  Ensino Fundamental         3.0  ...  2024-03-19
#
#                                           observacao  \
# 0  Atendimento:\r\n-2ª a 6ª feira, das 7h30 às 11...
# 1  Junto à escola funciona a Biblioteca Escolar B...
# 2     Equipamento em fase de implantação.\r\nUE-MZ-8
# 3  Junto à escola funciona a Biblioteca Escolar P...
# 4  Junto à escola funciona a Biblioteca Escolar M...
#
#                               fonte cd_mantene  \
# 0  Secretaria Municipal da Educação       13.0
# 1  Secretaria Municipal da Educação       13.0
# 2  Secretaria Municipal da Educação       13.0
# 3  Secretaria Municipal da Educação       13.0
# 4  Secretaria Municipal da Educação       13.0
#
#                          ds_mantene sigla_mant inativo_eq    lat_sirgas  \
# 0  Secretaria Municipal da Educação        SME          0  -25.43615422
# 1  Secretaria Municipal da Educação        SME          0  -25.41816609
# 2  Secretaria Municipal da Educação        SME          0  -25.43223321
# 3  Secretaria Municipal da Educação        SME          0  -25.44171582
# 4  Secretaria Municipal da Educação        SME          0  -25.45270199
#
#      lon_sirgas                                               geom
# 0  -49.28174386  0101000020E6100000BCB7C32F28882441BEA19CC43A69...
# 1  -49.26369031  0101000020E61000001A61E2B08B96244145F93703276B...
# 2  -49.24105262  0101000020E61000009C9369172DA82441446C78029A69...
# 3  -49.25801974  0101000020E61000006C3EB56BBC9A24412B576F049968...
# 4  -49.28171179  0101000020E6100000AFBB6163FF872441A9917D857067...
#
# [5 rows x 52 columns]

# %%
# !sudo shp2pgsql -c -I -s 4326 -W "latin1" /content/drive/MyDrive/Dados/CMEI.shp public.cmeis1 | psql -d postgres -U root > /dev/null 2>&1

df_cmeis = %sql SELECT * FROM cmeis1
df_cmeis.head()
# Out:
# Field cd_equi is an FTDouble with width 10 and precision 0
# Field cd_tema is an FTDouble with width 10 and precision 0
# Field id_equip is an FTDouble with width 10 and precision 0
# Field cd_tipo_eq is an FTDouble with width 10 and precision 0
# Field cd_dep_adm is an FTDouble with width 10 and precision 0
# Field cd_distrit is an FTDouble with width 10 and precision 0
# Field cd_equi_di is an FTDouble with width 10 and precision 0
# Field cd_mantene is an FTDouble with width 10 and precision 0
# Field lat_sirgas is an FTDouble with width 19 and precision 8
# Field lon_sirgas is an FTDouble with width 19 and precision 8
# Shapefile type: Point
# Postgis type: POINT[2]
#  * postgresql+psycopg2://@/postgres
#    gid  cd_equi  cd_local  cd_tema      tema  id_equip  \
# 0    1    749.0  41162633     11.0  EDUCAÇÃO      21.0
# 1    2    986.0  41356039     11.0  EDUCAÇÃO      21.0
# 2    3    987.0  41356063     11.0  EDUCAÇÃO      21.0
# 3    4   3317.0      None     11.0  EDUCAÇÃO      21.0
# 4    5  10120.0  41151259     11.0  EDUCAÇÃO      21.0
#
#                     equipament  cd_tipo_eq          tipo_equi  cd_dep_adm  \
# 0  Centro de Educação Infantil         2.0  Educação Infantil         3.0
# 1  Centro de Educação Infantil         2.0  Educação Infantil         3.0
# 2  Centro de Educação Infantil         2.0  Educação Infantil         3.0
# 3  Centro de Educação Infantil         2.0  Educação Infantil         3.0
# 4  Centro de Educação Infantil         2.0  Educação Infantil         3.0
#
#    ...  dt_atualiz                                         observacao  \
# 0  ...  2024-07-04  Atendimento:\r\n-2ª a 6ª feira, das 7h às 18h\...
# 1  ...  2024-07-04  Atendimento:\r\n-2ª a 6ª feira, das 7h às 18h\...
# 2  ...  2024-07-04  Atendimento:\r\n-2ª a 6ª feira, das 7h às 18h\...
# 3  ...  2024-07-04  Atendimento:\r\n-2ª a 6ª feira, das 7h às 18h\...
# 4  ...  2024-07-04  Atendimento:\r\n-2ª a 6ª feira, das 7h às 18h\...
#
#                               fonte cd_mantene  \
# 0  Secretaria Municipal da Educação       13.0
# 1  Secretaria Municipal da Educação       13.0
# 2  Secretaria Municipal da Educação       13.0
# 3  Secretaria Municipal da Educação       13.0
# 4  Secretaria Municipal da Educação       13.0
#
#                          ds_mantene sigla_mant inativo_eq    lat_sirgas  \
# 0  Secretaria Municipal da Educação        SME          0  -25.42991345
# 1  Secretaria Municipal da Educação        SME          0  -25.41293055
# 2  Secretaria Municipal da Educação        SME          0  -25.44862455
# 3  Secretaria Municipal da Educação        SME          0  -25.44985346
# 4  Secretaria Municipal da Educação        SME          0  -25.44406008
#
#      lon_sirgas                                               geom
# 0  -49.27771063  0101000020E61000003DF39D5B658B2441D8BE0C47E669...
# 1  -49.27054685  0101000020E61000009C45994137912441690B923BBA6B...
# 2  -49.27116424  0101000020E61000003BC2528C54902441DEFEFB00DE67...
# 3  -49.26908307  0101000020E6100000AE96D89DF391244138E2464BBB67...
# 4  -49.25843828  0101000020E610000041684772619A24419146E93C5868...
#
# [5 rows x 52 columns]

# %%
# !sudo shp2pgsql -c -I -s 4326 -W "latin1" /content/drive/MyDrive/Dados/CEI_CONVENIADA.shp public.ceis1 | psql -d postgres -U root > /dev/null 2>&1

df_ceis = %sql SELECT * FROM ceis1
df_ceis.head()
# Out:
# Field cd_equi is an FTDouble with width 10 and precision 0
# Field cd_tema is an FTDouble with width 10 and precision 0
# Field id_equip is an FTDouble with width 10 and precision 0
# Field cd_tipo_eq is an FTDouble with width 10 and precision 0
# Field cd_dep_adm is an FTDouble with width 10 and precision 0
# Field cd_distrit is an FTDouble with width 10 and precision 0
# Field cd_equi_di is an FTDouble with width 10 and precision 0
# Field cd_mantene is an FTDouble with width 10 and precision 0
# Field lat_sirgas is an FTDouble with width 19 and precision 8
# Field lon_sirgas is an FTDouble with width 19 and precision 8
# Shapefile type: Point
# Postgis type: POINT[2]
#  * postgresql+psycopg2://@/postgres
#    gid  cd_equi  cd_local  cd_tema      tema  id_equip  \
# 0    1   3395.0  41377451     11.0  EDUCAÇÃO      21.0
# 1    2    754.0  41356551     11.0  EDUCAÇÃO      21.0
# 2    3   8333.0      None     11.0  EDUCAÇÃO      21.0
# 3    4   1676.0  41149424     11.0  EDUCAÇÃO      21.0
# 4    5   1840.0  41149572     11.0  EDUCAÇÃO      21.0
#
#                     equipament  cd_tipo_eq          tipo_equi  cd_dep_adm  \
# 0  Centro de Educação Infantil         2.0  Educação Infantil        11.0
# 1  Centro de Educação Infantil         2.0  Educação Infantil        11.0
# 2  Centro de Educação Infantil         2.0  Educação Infantil        11.0
# 3  Centro de Educação Infantil         2.0  Educação Infantil        11.0
# 4  Centro de Educação Infantil         2.0  Educação Infantil        11.0
#
#    ...  dt_atualiz                                         observacao  \
# 0  ...  2024-04-22  Atendimento:\r\n-2ª a 6ª feira, das 7h às 18h3...
# 1  ...  2024-02-22  Atendimento:\r\n-2ª a 6ª feira, das 7h às 18h\...
# 2  ...  2024-10-10                                               None
# 3  ...  2024-02-23  Atendimento:\r\n-2ª a 6ª feira, das 8h às 19h\...
# 4  ...  2024-02-23  Atendimento:\r\n-2ª a 6ª feira, da 7h30 às 18h...
#
#                               fonte cd_mantene ds_mantene sigla_mant  \
# 0  Secretaria Municipal da Educação        0.0       None       None
# 1  Secretaria Municipal da Educação        0.0       None       None
# 2  Secretaria Municipal da Educação        0.0       None       None
# 3  Secretaria Municipal da Educação        0.0       None       None
# 4  Secretaria Municipal da Educação        0.0       None       None
#
#   inativo_eq    lat_sirgas    lon_sirgas  \
# 0          0  -25.50363656  -49.27417020
# 1          0  -25.42048211  -49.22960589
# 2          0  -25.54259670  -49.28784227
# 3          0  -25.41493012  -49.32801334
# 4          0  -25.45534558  -49.29020388
#
#                                                 geom
# 0  0101000020E610000081E4D3FC598D2441503CA798EB61...
# 1  0101000020E61000002424025C4EB124411E094E9DDB6A...
# 2  0101000020E61000001438661A2E82244158FD9A27B95D...
# 3  0101000020E61000000E6119AD07642441CADA1C47956B...
# 4  0101000020E6100000A24496DA4B812441CA36DA0F2A67...
#
# [5 rows x 52 columns]

# %%
# %%sql
# DROP TABLE IF EXISTS disp_educacionais CASCADE;
#
# CREATE TABLE disp_educacionais AS
# SELECT *
# FROM escolas1
# UNION ALL
# SELECT *
# FROM cmeis1
# UNION ALL
# SELECT *
# FROM ceis1;
# Out:
#  * postgresql+psycopg2://@/postgres
# Empty DataFrame
# Columns: []
# Index: []

# %%
df_todas_instituicoes = %sql SELECT * FROM disp_educacionais;
df_todas_instituicoes.head()
# Out:
#  * postgresql+psycopg2://@/postgres
#    gid  cd_equi  cd_local  cd_tema      tema  id_equip equipament  cd_tipo_eq  \
# 0    1  10880.0  41149378     11.0  EDUCAÇÃO      22.0     Escola         1.0
# 1    2   5315.0  41537904     11.0  EDUCAÇÃO      22.0     Escola         1.0
# 2    3   8417.0      None     11.0  EDUCAÇÃO      22.0     Escola         1.0
# 3    4   5314.0  41537890     11.0  EDUCAÇÃO      22.0     Escola         1.0
# 4    5   1620.0  41133323     11.0  EDUCAÇÃO      22.0     Escola         1.0
#
#             tipo_equi  cd_dep_adm  ...  dt_atualiz  \
# 0  Ensino Fundamental         3.0  ...  2024-03-08
# 1  Ensino Fundamental         3.0  ...  2024-03-08
# 2  Ensino Fundamental         3.0  ...  2024-07-08
# 3  Ensino Fundamental         3.0  ...  2024-09-16
# 4  Ensino Fundamental         3.0  ...  2024-03-19
#
#                                           observacao  \
# 0  Atendimento:\r\n-2ª a 6ª feira, das 7h30 às 11...
# 1  Junto à escola funciona a Biblioteca Escolar B...
# 2     Equipamento em fase de implantação.\r\nUE-MZ-8
# 3  Junto à escola funciona a Biblioteca Escolar P...
# 4  Junto à escola funciona a Biblioteca Escolar M...
#
#                               fonte cd_mantene  \
# 0  Secretaria Municipal da Educação       13.0
# 1  Secretaria Municipal da Educação       13.0
# 2  Secretaria Municipal da Educação       13.0
# 3  Secretaria Municipal da Educação       13.0
# 4  Secretaria Municipal da Educação       13.0
#
#                          ds_mantene sigla_mant inativo_eq    lat_sirgas  \
# 0  Secretaria Municipal da Educação        SME          0  -25.43615422
# 1  Secretaria Municipal da Educação        SME          0  -25.41816609
# 2  Secretaria Municipal da Educação        SME          0  -25.43223321
# 3  Secretaria Municipal da Educação        SME          0  -25.44171582
# 4  Secretaria Municipal da Educação        SME          0  -25.45270199
#
#      lon_sirgas                                               geom
# 0  -49.28174386  0101000020E6100000BCB7C32F28882441BEA19CC43A69...
# 1  -49.26369031  0101000020E61000001A61E2B08B96244145F93703276B...
# 2  -49.24105262  0101000020E61000009C9369172DA82441446C78029A69...
# 3  -49.25801974  0101000020E61000006C3EB56BBC9A24412B576F049968...
# 4  -49.28171179  0101000020E6100000AFBB6163FF872441A9917D857067...
#
# [5 rows x 52 columns]

# %%
import geopandas as gpd
import folium
from shapely import wkt
import matplotlib.cm as cm
import matplotlib.colors as colors
import matplotlib.pyplot as plt # Adicionado para a nova forma de obter colormaps

# Consulta todas as instituições educacionais
consulta_todas_instituicoes = """
    SELECT gid, equipament, tipo_equi, lat_sirgas, lon_sirgas
    FROM disp_educacionais
"""
df_all_instituicoes = %sql $consulta_todas_instituicoes

if not df_all_instituicoes.empty:
    # Cria a coluna de geometria a partir de lat_sirgas e lon_sirgas
    gdf_all_instituicoes = gpd.GeoDataFrame(
        df_all_instituicoes,
        geometry=gpd.points_from_xy(df_all_instituicoes['lon_sirgas'], df_all_instituicoes['lat_sirgas']),
        crs='EPSG:4326'
    )

    # Cria um mapa de cores para 'tipo_equi'
    unique_tipos = gdf_all_instituicoes['tipo_equi'].unique()
    num_colors = len(unique_tipos)

    # Usar matplotlib.colormaps.get_cmap como recomendado para evitar o aviso de depreciação
    cmap_name = 'tab10' if num_colors <= 10 else 'gist_rainbow' # Escolhe o colormap
    cmap = plt.colormaps.get_cmap(cmap_name) # Obtém o objeto colormap

    color_map = {}
    if num_colors > 0:
        for i, tipo in enumerate(unique_tipos):
            # Normaliza o índice para o colormap, tratando o caso de um único tipo
            normalized_i = i / (num_colors - 1) if num_colors > 1 else 0.0
            color_map[tipo] = colors.to_hex(cmap(normalized_i))

    # Calcula o centro e o zoom para o mapa baseado em todas as instituições
    minx, miny, maxx, maxy = gdf_all_instituicoes.total_bounds
    centro_lat = (miny + maxy) / 2
    centro_lon = (minx + maxx) / 2

    # Ajusta o zoom para cobrir todas as instituições
    mapa_nao_interativo = folium.Map(location=[centro_lat, centro_lon], zoom_start=11)

    # Adiciona todas as instituições ao mapa iterando e criando CircleMarkers
    for idx, row in gdf_all_instituicoes.iterrows():
        folium.CircleMarker(
            location=[row.geometry.y, row.geometry.x],
            radius=5,
            fill_color=color_map[row['tipo_equi']],
            color='black',
            weight=1,
            fill_opacity=0.7,
            tooltip=f"Instituição: {row['equipament']}<br>Tipo: {row['tipo_equi']}"
        ).add_to(mapa_nao_interativo)

    # Adiciona uma legenda para os tipos de instituição
    if color_map:
        legend_html = '<div style="position: fixed; bottom: 50px; left: 50px; width: 200px; background-color: white; border:2px solid grey; z-index:9999; font-size:14px; padding: 10px;">'
        legend_html += '<b>Tipo de Instituição</b><br>'
        for tipo, color in color_map.items():
            legend_html += f'<i style="background:{color}; width:10px; height:10px; display:inline-block; margin-right:5px;"></i>{tipo}<br>'
        legend_html += '</div>'
        mapa_nao_interativo.get_root().html.add_child(folium.Element(legend_html))

    folium.LayerControl().add_to(mapa_nao_interativo)
    display(mapa_nao_interativo)
else:
    print("Nenhuma instituição educacional encontrada na tabela 'disp_educacionais'.")
# Out:
#  * postgresql+psycopg2://@/postgres
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_c9ebd9fe1dc5bfa7134bade561660972 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position: fixed; bottom: 50px; left: 50px; width: 200px; background-color: white; border:2px solid grey; z-index:9999; font-size:14px; padding: 10px;&quot;&gt;&lt;b&gt;Tipo de Instituição&lt;/b&gt;&lt;br&gt;&lt;i style=&quot;background:#1f77b4; width:10px; height:10px; display:inline-block; margin-right:5px;&quot;&gt;&lt;/i&gt;Ensino Fundamental&lt;br&gt;&lt;i style=&quot;background:#8c564b; width:10px; height:10px; display:inline-block; margin-right:5px;&quot;&gt;&lt;/i&gt;Educação Especial&lt;br&gt;&lt;i style=&quot;background:#17becf; width:10px; height:10px; display:inline-block; margin-right:5px;&quot;&gt;&lt;/i&gt;Educação Infantil&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_c9ebd9fe1dc5bfa7134bade561660972&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_c9ebd9fe1dc5bfa7134bade561660972 = L.map(
#                 &quot;map_c9ebd9fe1dc5bfa7134bade561660972&quot;,
#                 {
#                     center: [-25.485603445000002, -49.28563923],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 11,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_7f6b0b73a81d9b0009b9efe335ae9125 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_7f6b0b73a81d9b0009b9efe335ae9125.addTo(map_c9ebd9fe1dc5bfa7134bade561660972);
#
#
#             var circle_marker_190b96713b39804a0317f73009fd0082 = L.circleMarker(
#                 [-25.43615422, -49.28174386],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c9ebd9fe1dc5bfa7134bade561660972);
#
#
#             circle_marker_190b96713b39804a0317f73009fd0082.bindTooltip(
#                 `&lt;div&gt;
#                      Instituição: Escola&lt;br&gt;Tipo: Ensino Fundamental
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_f37ca5a8097702268190d85c6125532e = L.circleMarker(
#                 [-25.41816609, -49.26369031],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c9ebd9fe1dc5bfa7134bade561660972);
#
#
#             circle_marker_f37ca5a8097702268190d85c6125532e.bindTooltip(
#                 `&lt;div&gt;
#                      Instituição: Escola&lt;br&gt;Tipo: Ensino Fundamental
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_44c572b90096628394d9be046a9a58b2 = L.circleMarker(
#                 [-25.43223321, -49.24105262],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#1f77b4&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 5, &quot;stroke&quot;: true, &quot;weight&quot;: 1}
#             ).addTo(map_c9ebd9fe1dc5bfa7134bade561660972);
#
#
#             circle_marker_44c572b90096628394d9be046a9a58b2.bindTooltip(
#                 `&lt;div&gt;
#                      Instituição: Escola&lt;br&gt;Tipo: Ensino Fundamental
#                  &lt;/div&gt;`,
#                 {
#   &quot;sticky&quot;: true,
# }
#             );
#
#
#             var circle_marker_6ff91201df494870352bdb121f974bc9 = L.circleMarker(
#                 [-25.44171582, -49.25801974],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;black&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: t

# %%
from ipywidgets import Dropdown
from IPython.display import display, clear_output
import pandas as pd
import geopandas as gpd
import folium
from shapely import wkt
import matplotlib.cm as cm
import matplotlib.colors as colors

# 1. Buscar bairros
df_bairros = %sql SELECT codigo, nome FROM bairros1 ORDER BY nome

# 2. Criar Dropdown
comboMun = Dropdown(
    options=[(row['nome'], row['codigo']) for _, row in df_bairros.iterrows()],
    description='Bairros:'
)

# 3. Função para atualizar o mapa
def atualizar_mapa(change):
    if change['type'] == 'change' and change['name'] == 'value':
        clear_output(wait=True)
        display(comboMun)

        codigo = comboMun.value
        selected_bairro_name = comboMun.label # Get the name of the selected bairro

        # Consulta bairro selecionado (original shape)
        consulta_sel = f"""
            SELECT codigo, nome, ST_AsText(ST_Transform(geom, 4326)) AS geom
            FROM bairros1
            WHERE codigo = '{codigo}'
        """
        df_sel = %sql $consulta_sel
        df_sel['geometry'] = df_sel['geom'].apply(wkt.loads)
        gdf_sel = gpd.GeoDataFrame(df_sel, geometry='geometry', crs='EPSG:4326')

        # Consulta todas as instituições educacionais dentro do bairro selecionado
        consulta_todas_instituicoes = f"""
            SELECT gid, equipament, tipo_equi, lat_sirgas, lon_sirgas
            FROM disp_educacionais d, bairros1 b
            WHERE b.codigo = {codigo}
              AND ST_Within(ST_SetSRID(ST_MakePoint(d.lon_sirgas, d.lat_sirgas), 4326), b.geom)
        """
        df_all_instituicoes = %sql $consulta_todas_instituicoes

        if not df_all_instituicoes.empty:
            # Create GeoDataFrame from lat_sirgas and lon_sirgas
            gdf_all_instituicoes = gpd.GeoDataFrame(
                df_all_instituicoes,
                geometry=gpd.points_from_xy(df_all_instituicoes['lon_sirgas'], df_all_instituicoes['lat_sirgas']),
                crs='EPSG:4326'
            )

            # Create a color map for 'tipo_equi'
            unique_tipos = gdf_all_instituicoes['tipo_equi'].unique()
            num_colors = len(unique_tipos)
            # Use a categorical colormap for better distinction
            cmap = cm.get_cmap('tab10' if num_colors <= 10 else 'gist_rainbow', num_colors)
            color_map = {tipo: colors.to_hex(cmap(i)) for i, tipo in enumerate(unique_tipos)}
        else:
            # Create an empty GeoDataFrame consistent with the selected columns
            gdf_all_instituicoes = gpd.GeoDataFrame(columns=[
                'gid', 'equipament', 'tipo_equi', 'lat_sirgas', 'lon_sirgas', 'geometry'
            ], geometry='geometry', crs='EPSG:4326')
            color_map = {} # Empty color map if no institutions

        # Criar o mapa
        centro = gdf_sel.geometry.centroid.iloc[0]
        mapa = folium.Map(location=[centro.y, centro.x], zoom_start=12) # Aumenta o zoom para ver as instituições

        # Adiciona bairro selecionado em azul com tooltip (formato original)
        folium.GeoJson(gdf_sel,
                       name="Bairro selecionado",
                       style_function=lambda x: {"fillColor": "blue", "color": "blue", "weight": 2, "fillOpacity": 0.4},
                       tooltip=folium.GeoJsonTooltip(fields=['nome'], aliases=['Bairro:'])
                      ).add_to(mapa)

        # Adiciona instituições educacionais usando CircleMarkers
        if not gdf_all_instituicoes.empty:
            for idx, row in gdf_all_instituicoes.iterrows():
                folium.CircleMarker(
                    location=[row.geometry.y, row.geometry.x],
                    radius=5,
                    fill_color=color_map[row['tipo_equi']],
                    color='black', # Border color
                    weight=1,
                    fill_opacity=0.7,
                    tooltip=f"Instituição: {row['equipament']}<br>Tipo: {row['tipo_equi']}"
                ).add_to(mapa)

        # Adiciona legenda bom base nos tipos de instituições
        if color_map:
            legend_html = '<div style="position: fixed; bottom: 50px; left: 50px; width: 200px; background-color: white; border:2px solid grey; z-index:9999; font-size:14px; padding: 10px;">'
            legend_html += '<b>Tipo de Instituição</b><br>'
            for tipo, color in color_map.items():
                legend_html += f'<i style="background:{color}; width:10px; height:10px; display:inline-block; margin-right:5px;"></i>{tipo}<br>'
            legend_html += '</div>'
            mapa.get_root().html.add_child(folium.Element(legend_html))

        folium.LayerControl().add_to(mapa)
        display(mapa)

# 4. Conectar a função ao Dropdown
comboMun.observe(atualizar_mapa)

# 5. Mostrar o Dropdown
display(comboMun)
# Out:
# Dropdown(description='Bairros:', index=30, options=(('ABRANCHES', 50.0), ('ÁGUA VERDE', 9.0), ('AHÚ', 14.0), (…
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
# /tmp/ipykernel_868/3122467364.py:59: MatplotlibDeprecationWarning: The get_cmap function was deprecated in Matplotlib 3.7 and will be removed in 3.11. Use ``matplotlib.colormaps[name]`` or ``matplotlib.colormaps.get_cmap()`` or ``pyplot.get_cmap()`` instead.
#   cmap = cm.get_cmap('tab10' if num_colors <= 10 else 'gist_rainbow', num_colors)
# /tmp/ipykernel_868/3122467364.py:69: UserWarning: Geometry is in a geographic CRS. Results from 'centroid' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   centro = gdf_sel.geometry.centroid.iloc[0]
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3cbeb03ef18322b070b3960f98d3c84a {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#             &lt;style&gt;html, body {
#                 width: 100%;
#                 height: 100%;
#                 margin: 0;
#                 padding: 0;
#             }
#             &lt;/style&gt;
#
#             &lt;style&gt;#map {
#                 position:absolute;
#                 top:0;
#                 bottom:0;
#                 right:0;
#                 left:0;
#                 }
#             &lt;/style&gt;
#
#             &lt;script&gt;
#                 L_NO_TOUCH = false;
#                 L_DISABLE_3D = false;
#             &lt;/script&gt;
#
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#     &lt;div style=&quot;position: fixed; bottom: 50px; left: 50px; width: 200px; background-color: white; border:2px solid grey; z-index:9999; font-size:14px; padding: 10px;&quot;&gt;&lt;b&gt;Tipo de Instituição&lt;/b&gt;&lt;br&gt;&lt;i style=&quot;background:#1f77b4; width:10px; height:10px; display:inline-block; margin-right:5px;&quot;&gt;&lt;/i&gt;Ensino Fundamental&lt;br&gt;&lt;/div&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3cbeb03ef18322b070b3960f98d3c84a&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3cbeb03ef18322b070b3960f98d3c84a = L.map(
#                 &quot;map_3cbeb03ef18322b070b3960f98d3c84a&quot;,
#                 {
#                     center: [-25.434482476764035, -49.24332800998948],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 12,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#
#
#
#
#
#             var tile_layer_395f01f467d7c64dd1e6a7b244fc3eeb = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_395f01f467d7c64dd1e6a7b244fc3eeb.addTo(map_3cbeb03ef18322b070b3960f98d3c84a);
#
#
#         function geo_json_1a44a427fcfe328752b64c0a74b48733_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;color&quot;: &quot;blue&quot;, &quot;fillColor&quot;: &quot;blue&quot;, &quot;fillOpacity&quot;: 0.4, &quot;weight&quot;: 2};
#             }
#         }
#
#         function geo_json_1a44a427fcfe328752b64c0a74b48733_onEachFeature(feature, layer) {
#
#             layer.on({
#             });
#         };
#         var geo_json_1a44a427fcfe328752b64c0a74b48733 = L.geoJson(null, {
#                 onEachFeature: geo_json_1a44a427fcfe328752b64c0a74b48733_onEachFeature,
#
#                 style: geo_json_1a44a427fcfe328752b64c0a74b48733_styler,
#             ...{
# }
#         });
#
#         function geo_json_1a44a427fcfe328752b64c0a74b48733_add (data) {
#             geo_json_1a44a427fcfe328752b64c0a74b48733
#                 .addData(data);
#         }
#             geo_json_1a44a427fcfe328752b64c0a74b48733_add({&quot;bbox&quot;: [-49.255705713008005, -25.441991829457884, -49.23358245901297, -25.42793459584282], &quot;features&quot;: [{&quot;bbox&quot;: [-49.255705713008005, -25.441991829457884, -49.23358245901297, -25.42793459584282], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[[-49.236391075281524, -25.43481332845368], [-49.23530118572857, -25.436415386528026], [-49.235296662590606, -25.436422038039158], [-49.23529587065232, -25.43642191501418], [-49.235293727911504, -25.436421584004794], [-49.235227649364006, -25.436411370391333], [-49.23445933090622, -25.436292601363544], [-49.233987294387475, -25.436219630535472], [-49.233986621711075, -25.436219527121114], [-49.233979043139314, -25.43621835600117], [-49.233955643865585, -25.436214738232128], [-49.233954552257025, -25.436233831564024], [-49.233950727347484, -25.436300576898862], [-49.23393762658478, -25.436529168432163], [-49.23393428077479, -25.436587568886956], [-49.23392867042359, -25.436685527603057], [-49.23392647011517, -25.436723927300854], [-49.233878369057486, -25.43699250111795], [-49.233865923711484, -25.43706201356463], [-49.2338355199935, -25.437231777763593], [-49.23372740817982, -25.437835443272505], [-49.23366710100793, -25.43817218225189], [-49.23360916262077, -25.438580545273886], [-49.233601143484975, -25.438684395623437], [-49.23358680808845, -25.438870040927966], [-49.23358565074354, -25.43888502233288], [-49.23358245901297, -25.43892635140257], [-49.23358276906306, -25.43895443155668], [-49.23358351343813, -25.439021997719397], [-49.23358618731149, -25.43926465616219], [-49.233607947572274, -25.440221873498736], [-49.23361894483752, -25.440705655915654], [-49.23362576199695, -25.441005600833023], [-49.23363436258355, -25.441372392635646], [-49.233645175931606, -25.441833462146544], [-49.23364583853643, -25.44186179228484], [-49.2336458831889, -25.441863639824053], [-49.23364592438188, -25.44186543332217], [-49.233648769649264, -25.44198677789369

# %%
import folium
import geopandas as gpd
from shapely import wkt

# Reload the sql extension to try and clear sticky configs
# %reload_ext sql
# %config SqlMagic.feedback=False
# %config SqlMagic.autopandas=True  # Ensure autopandas is enabled
# %sql postgresql+psycopg2://@/postgres

# Solicita as coordenadas ao usuário
try:
    input_lat = float(input("Digite a latitude (ex: -25.43): "))
    input_lon = float(input("Digite a longitude (ex: -49.27): "))
except ValueError:
    print("Entrada inválida. Por favor, digite números para latitude e longitude.")
    exit()

# Define a sessão PostGIS
# %sql SET SESSION search_path TO public;

# Consulta o bairro que contém o ponto inserido
# ST_MakePoint(longitude, latitude) - atenção à ordem
consulta_bairro = """
    SELECT nome, ST_AsText(geom) AS geometria
    FROM bairros1
    WHERE ST_Within(ST_SetSRID(ST_MakePoint(:input_lon, :input_lat), 4326), geom);
"""

# Execute the SQL query. With autopandas=True, this should directly return a DataFrame.
df_bairro_encontrado = %sql $consulta_bairro

# Cria o mapa Folium centrado no ponto inserido
mapa = folium.Map(location=[input_lat, input_lon], zoom_start=13)

# Adiciona o ponto inserido ao mapa
folium.Marker(
    location=[input_lat, input_lon],
    tooltip=f"Coordenadas: ({input_lat}, {input_lon})",
    icon=folium.Icon(color='green')
).add_to(mapa)

if not df_bairro_encontrado.empty:
    bairro_nome = df_bairro_encontrado['nome'].iloc[0]
    bairro_wkt = df_bairro_encontrado['geometria'].iloc[0]

    # Converte WKT para GeoDataFrame para adicionar ao Folium
    gdf_bairro = gpd.GeoDataFrame(
        {'nome': [bairro_nome]},
        geometry=[wkt.loads(bairro_wkt)],
        crs='EPSG:4326'
    )

    # Adiciona o polígono do bairro ao mapa
    folium.GeoJson(
        gdf_bairro,
        name=f"Bairro: {bairro_nome}",
        style_function=lambda x: {"fillColor": "orange", "color": "red", "weight": 2, "fillOpacity": 0.4},
        tooltip=folium.GeoJsonTooltip(fields=['nome'], aliases=['Bairro:'])
    ).add_to(mapa)

    print(f"O ponto ({input_lat}, {input_lon}) está dentro do bairro: {bairro_nome}")
else:
    print(f"O ponto ({input_lat}, {input_lon}) não foi encontrado em nenhum bairro registrado.")

# Exibe o mapa
folium.LayerControl().add_to(mapa)
display(mapa)
# Out:
# Digite a latitude (ex: -25.43): -25.43
# Digite a longitude (ex: -49.27): -49.27
#  * postgresql+psycopg2://@/postgres
#  * postgresql+psycopg2://@/postgres
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /tmp/ipykernel_28095/133175113.py in <cell line: 0>()
#      29
#      30 # Execute the SQL query. With autopandas=True, this should directly return a DataFrame.
# ---> 31 df_bairro_encontrado = get_ipython().run_line_magic('sql', '$consulta_bairro')
#      32
#      33 # Cria o mapa Folium centrado no ponto inserido
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2416                 kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2417             with self.builtin_trap:
# -> 2418                 result = fn(*args, **kwargs)
#    2419             return result
#    2420
#
# <decorator-gen-120> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# <decorator-gen-119> in execute(self, line, cell, local_ns)
#
# /usr/local/lib/python3.12/dist-packages/IPython/core/magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
#     189         if callable(arg):
#
# /usr/local/lib/python3.12/dist-packages/sql/magic.py in execute(self, line, cell, local_ns)
#     217
#     218         try:
# --> 219             result = sql.run.run(conn, parsed["sql"], self, user_ns)
#     220
#     221             if (
#
# /usr/local/lib/python3.12/dist-packages/sql/run.py in run(conn, sql, config, user_namespace)
#     372             if result and config.feedback:
#     373                 print(interpret_rowcount(result.rowcount))
# --> 374         resultset = ResultSet(result, config)
#     375         if config.autopandas:
#     376             return resultset.DataFrame()
#
# /usr/local/lib/python3.12/dist-packages/sql/run.py in __init__(self, sqlaproxy, config)
#     114                 list.__init__(self, sqlaproxy.fetchall())
#     115             self.field_names = unduplicate_field_names(self.keys)
# --> 116             self.pretty = PrettyTable(self.field_names, style=prettytable.__dict__[config.style.upper()])
#     117         else:
#     118             list.__init__(self, [])
#
# KeyError: 'PLAIN_COLUMNS'
